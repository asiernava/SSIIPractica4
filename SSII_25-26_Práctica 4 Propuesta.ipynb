# %% [markdown]
# ## 🛑 Complete los siguientes datos
#
# - Número de grupo:
# - Nombre y Apellidos de los integrantes:
# - Entrega:
# - Fecha:
# - Tiempo dedicado a la entrega:

# %% [markdown]
# # 🛑 Notas generales

# %% [markdown]
# -	Dos o más prácticas iguales o con un índice de similitud muy alto serán consideradas plagio por todos los implicados.
#
# -	Todas las prácticas son susceptibles de ser revisadas minuciosamente, incluyendo una defensa por parte de sus autores de forma individual. En caso de suspender esta defensa se suspendería la práctica.
#
# -	La práctica supone la realización de todos los apartados y el cumplimiento de todas las condiciones, si falta alguno, la práctica estará incompleta y no será evaluada.
#     -	<font color='red'>Las prácticas que no cumplan este requisito serán consideradas no válidas y obtendrán una calificación de 0.</font>
#
# -	Las prácticas han de ser funcionales y no dar error en su ejecución.
#     -	<font color='red'>Las prácticas que no cumplan este requisito serán consideradas no válidas y obtendrán una calificación de 0.</font>
# - El uso de código sin referenciar implicará la consideración de la práctica como no apta.

# %% [markdown]
# # 🛑 Instrucciones

# %% [markdown]
# Este es el cuaderno que utilizarás como **plantilla** para entrega de la práctica correpondiente.
#
# Por favor, **lee atentamente** el enunciado. Si tienes alguna duda, utiliza el foro o pregunta en clase (pero no compartas código).
#
# Consideraciones generales sobre el código:
# - Utilizar tantas celdas (de texto o de código) como considere para dar una respuesta legible y clara a las preguntas planteadas.
# - Mostrar resultados intermedios o finales (tablas, contenido de las variables...) que demuestren que la solución es correcta si fuera necesario.
# - No olvidéis importar todas las librerías necesarias para la correcta ejecución del código.
#
# En las indicaciones, hay instrucciones extra indicadas con el símbolo 🤖. No son requisitos para superar la práctica, sino acciones que puedes realizar para mejorar la calificación.
#
# La calificación de los ejercicios se hará con los siguientes criterios:
# - [9 a 10] puntos: La solución aportada cumple con los requisitos de forma excelente y existen aspectos positivos o extras (🤖) que avalan su excelencia.
# - [7 a 9] puntos: La solución aportada cumple con los requisitos, pero algunas cuestiones menores son susceptibles de ser mejoradas, tales como: presentación de la solución, justificación de la decisión tomada, eficiencia del código...
# - [5 a 7] puntos: Las soluciones aportadas no cumplen alguno de los requisitos, como por ejemplo: no se responde a una pregunta, no se aporta la solución a una parte...
# - [1 a 5] puntos: La solución aportada no cumple con varios requisitos.
# - [0] puntos: solución no aportada o solución plagiada. **Cabecera no completada, ficheros con nombre erróneo, etc.**
#
# La nota de la práctica dependerá de:
# 1.	Cumplimiento de las condiciones.
# 2.	Sofisticación del sistema.
# 3.  Limpieza y eficiencia del código.
# 4.  Comentarios aportados.

# %% [markdown]
# # 🛑 Desarrollo a realizar

# %% [markdown]
# En esta práctica tendrás que desarrollar un sistema inteligente relacionado con la [temática seleccionado](https://alud.deusto.es/mod/resource/view.php?id=888783) al inicio del curso.
#
# El problema a resolver ha de ser solucionable a partir de problema de búsquedas.
#
# Define un escenario que requiera algoritmos de búsqueda (por ejemplo, rutas de entrega entre varios puntos, localización de recursos, etc.).
# El proyecto debe incluir más de una búsqueda, no solo un único recorrido o punto de destino.
#
# **La elección de la temática y su correcta representación en Python será clave para poder resolver la práctica con éxito.**

# %% [markdown]
# # 🛑 Entrega

# %% [markdown]
# ## Validación del problema

# %% [markdown]
# Descripción del problema a resolver:

# %% [markdown]
# <font color="red">El problema consiste en desarrollar un sistema inteligente capaz de encontrar rutas óptimas para
#   trasladar cargas de trabajo entre servidores en un centro de datos. Este centro de datos se modela
#   como una matriz tridimensional de dos niveles, donde cada celda representa un servidor (identificado por un id) o un obstáculo ('X'). El objetivo es aplicar algoritmos de búsqueda como BFS, DFS, Greedy y A* para determinar caminos válidos y eficientes desde un servidor de origen hasta uno de destino, evitando los obstáculos y permitiendo la navegación entre los diferentes niveles del centro de datos.</font>

# %% [markdown]
# •	Confirmación del docente (fecha y comentarios):

# %% [markdown]
# <font color="red">Tu respuesta</font>

# %% [markdown]
# Representación de estados propuesta:

# %% [markdown]
# <font color="red">La representación de estados propuesta define cada estado como la posición actual de la carga de
#   trabajo (o agente) dentro del centro de datos. Esta posición se especifica mediante una tupla
#   (nivel, fila, columna), que indica el nivel, la fila y la columna exactas en la matriz
#   tridimensional del centro de datos. Además de la posición, cada estado puede incluir una referencia
#   a la matriz completa (para consultar el valor del servidor o si es un obstáculo) y un registro de
#   las acciones realizadas para llegar a dicho estado, lo que permite a los algoritmos de búsqueda
#   navegar y reconstruir el camino.</font>

# %% [markdown]
# •	Confirmación del docente (fecha y comentarios):

# %% [markdown]
# <font color="red">Tu respuesta</font>

# %% [markdown]
# ## Introducción

# %% [markdown]
# Breve descripción del problema.

# %% [markdown]
# <font color="red">Un grupo de servidores ha estado teniendo problemas ya que el envío de datos entre servidores era altamente ineficiente, lo que causaba retrasos importantes y causaba una mala experiencia para los clientes./font>

# %% [markdown]
# Contexto y finalidad del sistemas inteligente a implementar.

# %% [markdown]
# <font color="red">El sistema de busquedas desarrollado pretende agilizar el intercambio de información entre servidores buscando las rutas más óptimas entre los mismos mediante distintos algoritmos./font>

# %% [markdown]
# ## Programa

# %% [markdown]
# **Requisitos**
#
#   1. Utilizar la clase Nodo explicada en clase con los métodos y atributos vistos en los ejercicios prácticos.
#   2. Emplear métodos getters y setters como los requeridos en los ejericicos propuestos.
#   3. En la representación del problema han de existir obstáculos.
#   4. En la representación del problema han de existir varios niveles.
#   6. Utiliza una matriz (sin librerías) de al menos 2 niveles de 10x10.
#   7. En la representación del problema deben existir varios recursos u objetivos que actúen como base para realizar múltiples búsquedas (por ejemplo, varios paquetes/envíos, ubicaciones a visitar, elementos a recoger, etc.).
#   8. Resolver el problema empleando las versiones Graph de BFS, DFS, Greedy y A*.
#   9. Define [explícitamente](https://dle.rae.es/expl%C3%ADcitamente) un orden de visita en el caso de los algoritmos no informados.
#   10. Por cada iteración del algoritmo muestra <font color='purple'>los nodos expandidos</font> y la frontera.
#   11. Finalmente muestra la ruta encontrada y el coste.
#   12. Se han de relizar al menos 3 búsquedas.
#   13. **<font color="red">No es posible utilizar librerías.</font>**
#
#
# **Consideraciones deseables**
# * Desarrolla las versiones Tree de los algoritmos.
# * Utilizar dos versiones de A* y Greedy con 2 heurísticas.
# * El sistema ha de tener un grado de sofisticación elevado.
#
#
# **🤖Requisitos extra**
#
# * Proporcionar una representación visual de la ruta encontrada y de los nodos expandidos durante la búsqueda.
# * Comparar el rendimiento de los algoritmos (tiempo, nodos expandidos, coste de la ruta).

# %% [markdown]
# ### 1) Código

# %% [markdown]
# # ==============================================================================
# # SECCIÓN 1: INTRODUCCIÓN Y ESTRUCTURA DE DATOS
# # ==============================================================================

# %% [markdown]
# Matriz del centro de datos (2 niveles de 10x10)

# %%
matriz = [
    [   
        ['14', 'X',  '07', '88', '03', 'X',  '45', '12', 'X',  '30'],
        ['91', '55', '10', 'X',  '72', '61', '19', '84', '05', '22'],
        ['X',  'X',  '48', '31', '97', '06', 'X',  '73', '29', '13'],
        ['80', '52', 'X',  '94', '21', 'X',  '67', '11', 'X',  '32'],
        ['08', '76', 'X',  '44', '57', 'UP',  '90', '23', '04', '63'],
        ['X',  '26', '59', 'X',  '70', '41', '18', '39', '15', 'X'],
        ['87', '53', '24', 'X',  '92', '60', '78', 'X',  '36', '17'],
        ['X',  '02', '95', '50', 'X',  '66', '27', '46', 'X',  '58'],
        ['09', '43', '85', '07', 'X',  'X',  '34', '79', '25', 'X'],
        ['16', 'X',  '64', '38', '99', '12', '88', '55', '03', 'X']
    ],
    [   
        ['134','107','188','103','X',  '145','112','X',  '130','191'],
        ['X',  '155','110','X',  '172','161','119','184','105','122'],
        ['X',  '148','131','197','106','X',  '173','129','113','180'],
        ['152','X',  '194','121','X',  '167','111','X',  '132','108'],
        ['176','X',  '144','157','DOWN',  '190','123','104','X',  '163'],
        ['X',  '126','159','X',  '170','141','118','139','115','X'],
        ['187','153','124','X',  '192','160','178','X',  '136','117'],
        ['X',  '102','195','150','X',  '166','127','146','X',  'X'],
        ['158','109','143','185','137','X',  '133','179','125','X'],
        ['116','X',  '164','138','199','101','102','103','104','105']
    ]
]

# %% [markdown]
# Diccionarios de orígenes y destinos para pruebas

# %%
Lista_Origenes = {
    '55': (0, 1, 2),
    '30': (0, 0, 9),
    '07': (0, 0, 2),
    '145': (1, 0, 5),
    '194': (1, 3, 2),
    '26': (0, 5, 1),
    '78': (0, 6, 6)
}

Lista_Destinos = {
    '43': (0, 8, 1),
    '58': (0, 7, 9),
    '60': (0, 6, 5),
    '150': (1, 7, 3),
    '116': (1, 9, 0),
    '159': (1, 5, 2),
    '148': (1, 2, 1)
}

# %% [markdown]
# # ==============================================================================
# # SECCIÓN 2: CÓDIGO GENÉRICO - CLASES Y FUNCIONES COMPARTIDAS
# # ==============================================================================

# %% [markdown]
#  Clase Nodo que representa un nodo en el árbol/grafo de búsqueda

# %%
class Node:
   
    def __init__(self, parent=None, state=None, cost=0, action=None, depth=0, heuristic=0):
        self.parent = parent
        self.state = state
        self.cost = cost
        self.action = action
        self.depth = depth
        self.heuristic = heuristic
    
    def __str__(self):
        return str(self.state)
    
    def set_parent(self, parent):
        self.parent = parent
    
    def get_parent(self):
        return self.parent
    
    def set_state(self, state):
        self.state = state
    
    def get_state(self):
        return self.state
    
    def set_cost(self, cost):
        self.cost = cost
    
    def get_cost(self):
        return self.cost
    
    def set_action(self, action):
        self.action = action
    
    def get_action(self):
        return self.action
    
    def set_depth(self, depth):
        self.depth = depth
    
    def get_depth(self):
        return self.depth
    
    def set_heuristic(self, heuristic):
        self.heuristic = heuristic
    
    def get_heuristic(self):
        return self.heuristic
    
    def get_f_score(self):
        """Retorna f(n) = g(n) + h(n) para A*"""
        return self.cost + self.heuristic

# %% [markdown]
# Devuelve las posiciones vecinas válidas desde una posición dada.
# Maneja el cambio de nivel a través de portales UP/DOWN.
#
# ORDEN DE VISITA :
#     Los vecinos se generan en el siguiente orden:
#     1. Derecha (0, +1)
#     2. Abajo (+1, 0)
#     3. Izquierda (0, -1)
#     4. Arriba (-1, 0)
#     5. Cambio de nivel (UP/DOWN) si corresponde

# %%
def get_neighbors(matriz, position, goal_number):

    nivel, row, col = position
    rows = len(matriz[nivel])
    cols = len(matriz[nivel][0])
    neighbors = []
    
    goal_number = int(goal_number)
    target_level = 1 if goal_number > 99 else 0
    
    # Si estamos en el nivel equivocado, buscar el portal
    if nivel != target_level:
        directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]
        for dr, dc in directions:
            new_row = row + dr
            new_col = col + dc
            if 0 <= new_row < rows and 0 <= new_col < cols:
                if matriz[nivel][new_row][new_col] != 'X':
                    neighbors.append((nivel, new_row, new_col))
        
        current_value = matriz[nivel][row][col]
        
        if current_value == 'UP' and nivel + 1 < len(matriz):
            neighbors.append((nivel + 1, row, col))
        
        if current_value == 'DOWN' and nivel - 1 >= 0:
            neighbors.append((nivel - 1, row, col))
        
        return neighbors
    
    # Si estamos en el nivel correcto, moverse normalmente
    directions = [(0, 1), (1, 0), (0, -1), (-1, 0)]
    for dr, dc in directions:
        new_row = row + dr
        new_col = col + dc
        if 0 <= new_row < rows and 0 <= new_col < cols:
            if matriz[nivel][new_row][new_col] != 'X':
                neighbors.append((nivel, new_row, new_col))
    
    return neighbors

# %% [markdown]
# Expande un nodo generando sus sucesores.
#     Devuelve una lista de nodos hijo.

# %%
def expand(node_parent, matriz, goal_number):
  
    children = []
    for neighbor in get_neighbors(matriz, node_parent.get_state(), goal_number):
        child = Node()
        child.set_state(neighbor)
        child.set_parent(node_parent)
        child.set_action(get_neighbors(matriz, neighbor, goal_number))
        child.set_cost(node_parent.get_cost() + 1)
        child.set_depth(node_parent.get_depth() + 1)
        children.append(child)
    return children

# %% [markdown]
#  Calcula la distancia Manhattan entre dos posiciones (nivel, fila, columna)

# %%
def calculate_manhattan_distance(pos1, pos2):
   
    nivel1, row1, col1 = pos1
    nivel2, row2, col2 = pos2
    
    # Penalización por cambio de nivel
    level_penalty = abs(nivel1 - nivel2) * 5
    
    return abs(row1 - row2) + abs(col1 - col2) + level_penalty

# %% [markdown]
# Reconstruye el camino desde el nodo inicial hasta el nodo objetivo

# %%
def reconstruct_path(node):
    
    path = []
    temp_node = node
    while temp_node:
        path.append(temp_node.get_state())
        temp_node = temp_node.get_parent()
    path.reverse()
    return path

# %% [markdown]
# Imprime la solución encontrada de forma estandarizada

# %%
def print_solution(found, node, algorithm_name):
   
    if found:
        path = reconstruct_path(node)
        print(f"\n{'='*60}")
        print(f"¡OBJETIVO ENCONTRADO CON {algorithm_name}!")
        print(f"{'='*60}")
        print(f"Camino: {path}")
        print(f"Coste total: {node.get_cost()}")
        print(f"Profundidad: {node.get_depth()}")
        print(f"Nodos en el camino: {len(path)}")
        print(f"{'='*60}\n")
        return node
    else:
        print(f"\n{algorithm_name}: Solución no encontrada\n")
        return None

# %% [markdown]
# # ==============================================================================
# # SECCIÓN 3: BFS (BREADTH-FIRST SEARCH)
# # ==============================================================================

# %% [markdown]
#     BFS Tree Search: Búsqueda en anchura sin control de estados repetidos.
#     Explora por niveles, garantiza camino más corto si todos los costes son iguales.
#
#     ORDEN DE VISITA: FIFO (First In, First Out)
#     - Se extraen nodos con pop(0) - el más antiguo primero
#     - Los vecinos se añaden al final de la frontera
#     - Resultado: Exploración por niveles de profundidad

# %%
def bfs_tree(matriz, start, goal_number):
    
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    frontier.append(node1)
    
    print("\n--- INICIO BFS TREE SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        node_parent = frontier.pop(0)
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  Coste: {node_parent.get_cost()}, Profundidad: {node_parent.get_depth()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == str(goal_number):
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand(node_parent, matriz, goal_number)
        frontier.extend(next_nodes)
        
        print(f"  Frontera: {len(frontier)} nodos")
    
    return print_solution(found, node1, "BFS TREE")

# %% [markdown]
#     BFS Graph Search: Búsqueda en anchura con control de estados visitados.
#     Evita ciclos y estados repetidos.
#
#     ORDEN DE VISITA: FIFO (First In, First Out)
#     - Se extraen nodos con pop(0) - el más antiguo primero
#     - Los vecinos se añaden al final de la frontera
#     - Solo se añaden estados no visitados previamente
#     - Resultado: Exploración por niveles de profundidad sin repeticiones

# %%
def bfs_graph(matriz, start, goal_number):
    
    goal_number = str(goal_number)
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    explored = set()
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    frontier.append(node1)
    explored.add(start)
    
    print("\n--- INICIO BFS GRAPH SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        node_parent = frontier.pop(0)
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  Coste: {node_parent.get_cost()}, Profundidad: {node_parent.get_depth()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == goal_number:
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand(node_parent, matriz, goal_number)
        
        for child in next_nodes:
            child_state = child.get_state()
            if child_state not in explored:
                explored.add(child_state)
                frontier.append(child)
        
        print(f"  Frontera: {len(frontier)} nodos, Explorados: {len(explored)}")
    
    return print_solution(found, node1, "BFS GRAPH")

# %% [markdown]
# # ==============================================================================
# # SECCIÓN 4: DFS (DEPTH-FIRST SEARCH)
# # ==============================================================================

# %% [markdown]
#     DFS Tree Search: Búsqueda en profundidad sin control de estados repetidos.
#     Explora hasta el fondo antes de retroceder.
#
#     ORDEN DE VISITA: LIFO (Last In, First Out)
#     - Se extraen nodos con pop() - el más reciente primero
#     - Los vecinos se añaden al final de la frontera
#     - Resultado: Exploración en profundidad (rama completa antes de cambiar)

# %%
def dfs_tree(matriz, start, goal_number):
    
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    frontier.append(node1)
    
    print("\n--- INICIO DFS TREE SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        node_parent = frontier.pop()  # LIFO - Último en entrar, primero en salir
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  Coste: {node_parent.get_cost()}, Profundidad: {node_parent.get_depth()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == str(goal_number):
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand(node_parent, matriz, goal_number)
        frontier.extend(next_nodes)
        
        print(f"  Frontera: {len(frontier)} nodos")
    
    return print_solution(found, node1, "DFS TREE")

# %% [markdown]
#     DFS Graph Search: Búsqueda en profundidad con control de estados visitados.
#     Evita ciclos y estados repetidos.
#
#     ORDEN DE VISITA: LIFO (Last In, First Out)
#     - Se extraen nodos con pop() - el más reciente primero
#     - Los vecinos se añaden al final de la frontera
#     - Solo se añaden estados no visitados previamente
#     - Resultado: Exploración en profundidad sin repeticiones

# %%
def dfs_graph(matriz, start, goal_number):
    
    goal_number = str(goal_number)
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    explored = set()
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    frontier.append(node1)
    explored.add(start)
    
    print("\n--- INICIO DFS GRAPH SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        node_parent = frontier.pop()  # LIFO
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  Coste: {node_parent.get_cost()}, Profundidad: {node_parent.get_depth()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == goal_number:
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand(node_parent, matriz, goal_number)
        
        newly_added = []
        for child in next_nodes:
            child_state = child.get_state()
            if child_state not in explored:
                explored.add(child_state)
                newly_added.append(child)
        
        frontier.extend(newly_added)
        
        print(f"  Frontera: {len(frontier)} nodos, Explorados: {len(explored)}")
    
    return print_solution(found, node1, "DFS GRAPH")

# %% [markdown]
# # ==============================================================================
# # SECCIÓN 5: GREEDY (BEST-FIRST SEARCH)
# # ==============================================================================

# %% [markdown]
#     Expande un nodo y calcula la heurística para cada hijo.
#     La heurística es la distancia Manhattan al objetivo.

# %%
def expand_greedy(node_parent, matriz, goal_number, goal_position):
   
    children = []
    for neighbor in get_neighbors(matriz, node_parent.get_state(), goal_number):
        child = Node()
        child.set_state(neighbor)
        child.set_parent(node_parent)
        child.set_action(get_neighbors(matriz, neighbor, goal_number))
        child.set_cost(node_parent.get_cost() + 1)
        child.set_depth(node_parent.get_depth() + 1)
        
        heuristic = calculate_manhattan_distance(neighbor, goal_position)
        child.set_heuristic(heuristic)
        
        children.append(child)
    return children

# %% [markdown]
#     Greedy Tree Search: Búsqueda voraz que elige siempre el nodo con menor heurística.
#     Usa solo h(n), no considera el coste acumulado.

# %%
def greedy_tree(matriz, start, goal_number, goal_position):
   
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    heuristic = calculate_manhattan_distance(start, goal_position)
    node1.set_heuristic(heuristic)
    frontier.append(node1)
    
    print("\n--- INICIO GREEDY TREE SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        
        # Ordenar por heurística (menor primero)
        frontier.sort(key=lambda n: n.get_heuristic())
        
        node_parent = frontier.pop(0)
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  h(n): {node_parent.get_heuristic()}, Coste: {node_parent.get_cost()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == str(goal_number):
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand_greedy(node_parent, matriz, goal_number, goal_position)
        frontier.extend(next_nodes)
        
        print(f"  Frontera: {len(frontier)} nodos")
    
    return print_solution(found, node1, "GREEDY TREE")

# %% [markdown]
#     Greedy Graph Search: Búsqueda voraz con control de estados visitados.
#     Evita ciclos y estados repetidos.

# %%
def greedy_graph(matriz, start, goal_number, goal_position):
    
    goal_number = str(goal_number)
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    explored = set()
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    heuristic = calculate_manhattan_distance(start, goal_position)
    node1.set_heuristic(heuristic)
    frontier.append(node1)
    explored.add(start)
    
    print("\n--- INICIO GREEDY GRAPH SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        
        frontier.sort(key=lambda n: n.get_heuristic())
        
        node_parent = frontier.pop(0)
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  h(n): {node_parent.get_heuristic()}, Coste: {node_parent.get_cost()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == goal_number:
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand_greedy(node_parent, matriz, goal_number, goal_position)
        
        for child in next_nodes:
            child_state = child.get_state()
            if child_state not in explored:
                explored.add(child_state)
                frontier.append(child)
        
        print(f"  Frontera: {len(frontier)} nodos, Explorados: {len(explored)}")
    
    return print_solution(found, node1, "GREEDY GRAPH")

# %% [markdown]
# # ==============================================================================
# # SECCIÓN 6: A* (A-STAR)
# # ==============================================================================

# %% [markdown]
#     Expande un nodo y calcula tanto el coste como la heurística para cada hijo.
#     Para A*, se usa f(n) = g(n) + h(n)

# %%
def expand_astar(node_parent, matriz, goal_number, goal_position):
   
    children = []
    for neighbor in get_neighbors(matriz, node_parent.get_state(), goal_number):
        child = Node()
        child.set_state(neighbor)
        child.set_parent(node_parent)
        child.set_action(get_neighbors(matriz, neighbor, goal_number))
        child.set_cost(node_parent.get_cost() + 1)
        child.set_depth(node_parent.get_depth() + 1)
        
        heuristic = calculate_manhattan_distance(neighbor, goal_position)
        child.set_heuristic(heuristic)
        
        children.append(child)
    return children

# %% [markdown]
#     A* Tree Search: Búsqueda A* que usa f(n) = g(n) + h(n).
#     Combina coste real y estimado para encontrar caminos óptimos.

# %%
def astar_tree(matriz, start, goal_number, goal_position):
   
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    heuristic = calculate_manhattan_distance(start, goal_position)
    node1.set_heuristic(heuristic)
    frontier.append(node1)
    
    print("\n--- INICIO A* TREE SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        
        # Ordenar por f(n) = g(n) + h(n)
        frontier.sort(key=lambda n: n.get_f_score())
        
        node_parent = frontier.pop(0)
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  g(n): {node_parent.get_cost()}, h(n): {node_parent.get_heuristic()}, f(n): {node_parent.get_f_score()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == str(goal_number):
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand_astar(node_parent, matriz, goal_number, goal_position)
        frontier.extend(next_nodes)
        
        print(f"  Frontera: {len(frontier)} nodos")
    
    return print_solution(found, node1, "A* TREE")

# %% [markdown]
#     A* Graph Search: Búsqueda A* con control de estados visitados.
#     Garantiza encontrar el camino óptimo si la heurística es admisible.

# %%
def astar_graph(matriz, start, goal_number, goal_position):
   
    goal_number = str(goal_number)
    frontier = []
    found = False
    iteration_limit = 1000
    iterations = 0
    explored = set()
    
    node1 = Node()
    node1.set_parent(None)
    node1.set_state(start)
    node1.set_action(get_neighbors(matriz, start, goal_number))
    node1.set_cost(0)
    node1.set_depth(0)
    heuristic = calculate_manhattan_distance(start, goal_position)
    node1.set_heuristic(heuristic)
    frontier.append(node1)
    explored.add(start)
    
    print("\n--- INICIO A* GRAPH SEARCH ---")
    
    while not found and frontier and iterations < iteration_limit:
        iterations += 1
        
        frontier.sort(key=lambda n: n.get_f_score())
        
        node_parent = frontier.pop(0)
        current_state = node_parent.get_state()
        
        print(f"\nIteración {iterations} - Expandiendo: {current_state}")
        print(f"  g(n): {node_parent.get_cost()}, h(n): {node_parent.get_heuristic()}, f(n): {node_parent.get_f_score()}")
        
        valor_actual = matriz[current_state[0]][current_state[1]][current_state[2]]
        if str(valor_actual) == goal_number:
            found = True
            node1 = node_parent
            break
        
        next_nodes = expand_astar(node_parent, matriz, goal_number, goal_position)
        
        for child in next_nodes:
            child_state = child.get_state()
            if child_state not in explored:
                explored.add(child_state)
                frontier.append(child)
        
        print(f"  Frontera: {len(frontier)} nodos, Explorados: {len(explored)}")
    
    return print_solution(found, node1, "A* GRAPH")

# %% [markdown]
# ### 2) Caso de uso

# %%
def ejecutar_ejemplos():
    """Ejecuta varios ejemplos de búsqueda con diferentes algoritmos"""
    
    print("\n" + "="*80)
    print("EJEMPLOS DE BÚSQUEDA EN CENTRO DE DATOS")
    print("="*80)
    
    # Ejemplo 1: BFS - Del servidor 55 al 43
    print("\n" + "-"*80)
    print("EJEMPLO 1: BFS TREE - Servidor 55 (nivel 0) → Servidor 43 (nivel 0)")
    print("-"*80)
    origen1 = Lista_Origenes['55']
    destino1 = Lista_Destinos['43']
    bfs_tree(matriz, origen1, '43')
    
    # Ejemplo 2: BFS GRAPH - Del servidor 30 al 58
    print("\n" + "-"*80)
    print("EJEMPLO 2: BFS GRAPH - Servidor 30 (nivel 0) → Servidor 58 (nivel 0)")
    print("-"*80)
    origen2 = Lista_Origenes['30']
    destino2 = Lista_Destinos['58']
    bfs_graph(matriz, origen2, '58')
    
    # Ejemplo 3: DFS TREE - Del servidor 07 al 60
    print("\n" + "-"*80)
    print("EJEMPLO 3: DFS TREE - Servidor 07 (nivel 0) → Servidor 60 (nivel 0)")
    print("-"*80)
    origen3 = Lista_Origenes['07']
    destino3 = Lista_Destinos['60']
    dfs_tree(matriz, origen3, '60')
    
    # Ejemplo 4: DFS GRAPH - Del servidor 145 al 150
    print("\n" + "-"*80)
    print("EJEMPLO 4: DFS GRAPH - Servidor 145 (nivel 1) → Servidor 150 (nivel 1)")
    print("-"*80)
    origen4 = Lista_Origenes['145']
    destino4 = Lista_Destinos['150']
    dfs_graph(matriz, origen4, '150')
    
    # Ejemplo 5: GREEDY TREE - Del servidor 26 al 116
    print("\n" + "-"*80)
    print("EJEMPLO 5: GREEDY TREE - Servidor 26 (nivel 0) → Servidor 116 (nivel 1)")
    print("-"*80)
    origen5 = Lista_Origenes['26']
    destino5 = Lista_Destinos['116']
    greedy_tree(matriz, origen5, '116', destino5)
    
    # Ejemplo 6: GREEDY GRAPH - Del servidor 78 al 148
    print("\n" + "-"*80)
    print("EJEMPLO 6: GREEDY GRAPH - Servidor 78 (nivel 0) → Servidor 148 (nivel 1)")
    print("-"*80)
    origen6 = Lista_Origenes['78']
    destino6 = Lista_Destinos['148']
    greedy_graph(matriz, origen6, '148', destino6)
    
    # Ejemplo 7: A* TREE - Del servidor 194 al 159
    print("\n" + "-"*80)
    print("EJEMPLO 7: A* TREE - Servidor 194 (nivel 1) → Servidor 159 (nivel 1)")
    print("-"*80)
    origen7 = Lista_Origenes['194']
    destino7 = Lista_Destinos['159']
    astar_tree(matriz, origen7, '159', destino7)
    
    # Ejemplo 8: A* GRAPH - Del servidor 55 al 150
    print("\n" + "-"*80)
    print("EJEMPLO 8: A* GRAPH - Servidor 55 (nivel 0) → Servidor 150 (nivel 1)")
    print("-"*80)
    origen8 = Lista_Origenes['55']
    destino8 = Lista_Destinos['150']
    astar_graph(matriz, origen8, '150', destino8)

# %% [markdown]
# EJECUCIÓN PRINCIPAL

# %%
if __name__ == "__main__":
    ejecutar_ejemplos()
# Out:
# ================================================================================
# EJEMPLOS DE BÚSQUEDA EN CENTRO DE DATOS
# ================================================================================
#
# --------------------------------------------------------------------------------
# EJEMPLO 1: BFS TREE - Servidor 55 (nivel 0) → Servidor 43 (nivel 0)
# --------------------------------------------------------------------------------
#
# --- INICIO BFS TREE SEARCH ---
#
# Iteración 1 - Expandiendo: (0, 1, 2)
#   Coste: 0, Profundidad: 0
#   Frontera: 3 nodos
#
# Iteración 2 - Expandiendo: (0, 2, 2)
#   Coste: 1, Profundidad: 1
#   Frontera: 4 nodos
#
# Iteración 3 - Expandiendo: (0, 1, 1)
#   Coste: 1, Profundidad: 1
#   Frontera: 5 nodos
#
# Iteración 4 - Expandiendo: (0, 0, 2)
#   Coste: 1, Profundidad: 1
#   Frontera: 6 nodos
#
# Iteración 5 - Expandiendo: (0, 2, 3)
#   Coste: 2, Profundidad: 2
#   Frontera: 8 nodos
#
# Iteración 6 - Expandiendo: (0, 1, 2)
#   Coste: 2, Profundidad: 2
#   Frontera: 10 nodos
#
# Iteración 7 - Expandiendo: (0, 1, 2)
#   Coste: 2, Profundidad: 2
#   Frontera: 12 nodos
#
# Iteración 8 - Expandiendo: (0, 1, 0)
#   Coste: 2, Profundidad: 2
#   Frontera: 13 nodos
#
# Iteración 9 - Expandiendo: (0, 0, 3)
#   Coste: 2, Profundidad: 2
#   Frontera: 14 nodos
#
# Iteración 10 - Expandiendo: (0, 1, 2)
#   Coste: 2, Profundidad: 2
#   Frontera: 16 nodos
#
# Iteración 11 - Expandiendo: (0, 2, 4)
#   Coste: 3, Profundidad: 3
#   Frontera: 19 nodos
#
# Iteración 12 - Expandiendo: (0, 3, 3)
#   Coste: 3, Profundidad: 3
#   Frontera: 21 nodos
#
# Iteración 13 - Expandiendo: (0, 2, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 22 nodos
#
# Iteración 14 - Expandiendo: (0, 2, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 23 nodos
#
# Iteración 15 - Expandiendo: (0, 1, 1)
#   Coste: 3, Profundidad: 3
#   Frontera: 24 nodos
#
# Iteración 16 - Expandiendo: (0, 0, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 25 nodos
#
# Iteración 17 - Expandiendo: (0, 2, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 26 nodos
#
# Iteración 18 - Expandiendo: (0, 1, 1)
#   Coste: 3, Profundidad: 3
#   Frontera: 27 nodos
#
# Iteración 19 - Expandiendo: (0, 0, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 28 nodos
#
# Iteración 20 - Expandiendo: (0, 1, 1)
#   Coste: 3, Profundidad: 3
#   Frontera: 29 nodos
#
# Iteración 21 - Expandiendo: (0, 0, 0)
#   Coste: 3, Profundidad: 3
#   Frontera: 29 nodos
#
# Iteración 22 - Expandiendo: (0, 0, 4)
#   Coste: 3, Profundidad: 3
#   Frontera: 30 nodos
#
# Iteración 23 - Expandiendo: (0, 0, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 31 nodos
#
# Iteración 24 - Expandiendo: (0, 2, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 32 nodos
#
# Iteración 25 - Expandiendo: (0, 1, 1)
#   Coste: 3, Profundidad: 3
#   Frontera: 33 nodos
#
# Iteración 26 - Expandiendo: (0, 0, 2)
#   Coste: 3, Profundidad: 3
#   Frontera: 34 nodos
#
# Iteración 27 - Expandiendo: (0, 2, 5)
#   Coste: 4, Profundidad: 4
#   Frontera: 35 nodos
#
# Iteración 28 - Expandiendo: (0, 3, 4)
#   Coste: 4, Profundidad: 4
#   Frontera: 37 nodos
#
# Iteración 29 - Expandiendo: (0, 2, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 39 nodos
#
# Iteración 30 - Expandiendo: (0, 1, 4)
#   Coste: 4, Profundidad: 4
#   Frontera: 41 nodos
#
# Iteración 31 - Expandiendo: (0, 3, 4)
#   Coste: 4, Profundidad: 4
#   Frontera: 43 nodos
#
# Iteración 32 - Expandiendo: (0, 4, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 44 nodos
#
# Iteración 33 - Expandiendo: (0, 2, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 46 nodos
#
# Iteración 34 - Expandiendo: (0, 2, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 48 nodos
#
# Iteración 35 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 50 nodos
#
# Iteración 36 - Expandiendo: (0, 2, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 52 nodos
#
# Iteración 37 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 54 nodos
#
# Iteración 38 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 56 nodos
#
# Iteración 39 - Expandiendo: (0, 1, 0)
#   Coste: 4, Profundidad: 4
#   Frontera: 57 nodos
#
# Iteración 40 - Expandiendo: (0, 0, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 58 nodos
#
# Iteración 41 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 60 nodos
#
# Iteración 42 - Expandiendo: (0, 2, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 62 nodos
#
# Iteración 43 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 64 nodos
#
# Iteración 44 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 66 nodos
#
# Iteración 45 - Expandiendo: (0, 1, 0)
#   Coste: 4, Profundidad: 4
#   Frontera: 67 nodos
#
# Iteración 46 - Expandiendo: (0, 0, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 68 nodos
#
# Iteración 47 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 70 nodos
#
# Iteración 48 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 72 nodos
#
# Iteración 49 - Expandiendo: (0, 1, 0)
#   Coste: 4, Profundidad: 4
#   Frontera: 73 nodos
#
# Iteración 50 - Expandiendo: (0, 1, 0)
#   Coste: 4, Profundidad: 4
#   Frontera: 74 nodos
#
# Iteración 51 - Expandiendo: (0, 1, 4)
#   Coste: 4, Profundidad: 4
#   Frontera: 76 nodos
#
# Iteración 52 - Expandiendo: (0, 0, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 77 nodos
#
# Iteración 53 - Expandiendo: (0, 0, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 78 nodos
#
# Iteración 54 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 80 nodos
#
# Iteración 55 - Expandiendo: (0, 2, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 82 nodos
#
# Iteración 56 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 84 nodos
#
# Iteración 57 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 86 nodos
#
# Iteración 58 - Expandiendo: (0, 1, 0)
#   Coste: 4, Profundidad: 4
#   Frontera: 87 nodos
#
# Iteración 59 - Expandiendo: (0, 0, 3)
#   Coste: 4, Profundidad: 4
#   Frontera: 88 nodos
#
# Iteración 60 - Expandiendo: (0, 1, 2)
#   Coste: 4, Profundidad: 4
#   Frontera: 90 nodos
#
# Iteración 61 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 93 nodos
#
# Iteración 62 - Expandiendo: (0, 1, 5)
#   Coste: 5, Profundidad: 5
#   Frontera: 95 nodos
#
# Iteración 63 - Expandiendo: (0, 4, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 98 nodos
#
# Iteración 64 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 100 nodos
#
# Iteración 65 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 103 nodos
#
# Iteración 66 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 106 nodos
#
# Iteración 67 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 108 nodos
#
# Iteración 68 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 109 nodos
#
# Iteración 69 - Expandiendo: (0, 1, 5)
#   Coste: 5, Profundidad: 5
#   Frontera: 111 nodos
#
# Iteración 70 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 114 nodos
#
# Iteración 71 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 115 nodos
#
# Iteración 72 - Expandiendo: (0, 4, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 118 nodos
#
# Iteración 73 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 120 nodos
#
# Iteración 74 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 123 nodos
#
# Iteración 75 - Expandiendo: (0, 4, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 126 nodos
#
# Iteración 76 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 128 nodos
#
# Iteración 77 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 131 nodos
#
# Iteración 78 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 133 nodos
#
# Iteración 79 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 134 nodos
#
# Iteración 80 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 137 nodos
#
# Iteración 81 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 139 nodos
#
# Iteración 82 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 140 nodos
#
# Iteración 83 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 141 nodos
#
# Iteración 84 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 142 nodos
#
# Iteración 85 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 143 nodos
#
# Iteración 86 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 146 nodos
#
# Iteración 87 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 148 nodos
#
# Iteración 88 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 149 nodos
#
# Iteración 89 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 150 nodos
#
# Iteración 90 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 151 nodos
#
# Iteración 91 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 152 nodos
#
# Iteración 92 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 153 nodos
#
# Iteración 93 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 154 nodos
#
# Iteración 94 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 155 nodos
#
# Iteración 95 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 156 nodos
#
# Iteración 96 - Expandiendo: (0, 0, 0)
#   Coste: 5, Profundidad: 5
#   Frontera: 156 nodos
#
# Iteración 97 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 157 nodos
#
# Iteración 98 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 158 nodos
#
# Iteración 99 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 159 nodos
#
# Iteración 100 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 160 nodos
#
# Iteración 101 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 161 nodos
#
# Iteración 102 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 164 nodos
#
# Iteración 103 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 166 nodos
#
# Iteración 104 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 167 nodos
#
# Iteración 105 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 168 nodos
#
# Iteración 106 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 169 nodos
#
# Iteración 107 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 170 nodos
#
# Iteración 108 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 171 nodos
#
# Iteración 109 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 172 nodos
#
# Iteración 110 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 173 nodos
#
# Iteración 111 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 174 nodos
#
# Iteración 112 - Expandiendo: (0, 0, 0)
#   Coste: 5, Profundidad: 5
#   Frontera: 174 nodos
#
# Iteración 113 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 175 nodos
#
# Iteración 114 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 176 nodos
#
# Iteración 115 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 177 nodos
#
# Iteración 116 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 178 nodos
#
# Iteración 117 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 179 nodos
#
# Iteración 118 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 180 nodos
#
# Iteración 119 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 181 nodos
#
# Iteración 120 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 182 nodos
#
# Iteración 121 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 183 nodos
#
# Iteración 122 - Expandiendo: (0, 0, 0)
#   Coste: 5, Profundidad: 5
#   Frontera: 183 nodos
#
# Iteración 123 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 184 nodos
#
# Iteración 124 - Expandiendo: (0, 0, 0)
#   Coste: 5, Profundidad: 5
#   Frontera: 184 nodos
#
# Iteración 125 - Expandiendo: (0, 1, 5)
#   Coste: 5, Profundidad: 5
#   Frontera: 186 nodos
#
# Iteración 126 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 189 nodos
#
# Iteración 127 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 190 nodos
#
# Iteración 128 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 191 nodos
#
# Iteración 129 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 192 nodos
#
# Iteración 130 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 193 nodos
#
# Iteración 131 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 194 nodos
#
# Iteración 132 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 195 nodos
#
# Iteración 133 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 196 nodos
#
# Iteración 134 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 197 nodos
#
# Iteración 135 - Expandiendo: (0, 2, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 200 nodos
#
# Iteración 136 - Expandiendo: (0, 3, 3)
#   Coste: 5, Profundidad: 5
#   Frontera: 202 nodos
#
# Iteración 137 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 203 nodos
#
# Iteración 138 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 204 nodos
#
# Iteración 139 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 205 nodos
#
# Iteración 140 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 206 nodos
#
# Iteración 141 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 207 nodos
#
# Iteración 142 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 208 nodos
#
# Iteración 143 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 209 nodos
#
# Iteración 144 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 210 nodos
#
# Iteración 145 - Expandiendo: (0, 0, 0)
#   Coste: 5, Profundidad: 5
#   Frontera: 210 nodos
#
# Iteración 146 - Expandiendo: (0, 0, 4)
#   Coste: 5, Profundidad: 5
#   Frontera: 211 nodos
#
# Iteración 147 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 212 nodos
#
# Iteración 148 - Expandiendo: (0, 2, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 213 nodos
#
# Iteración 149 - Expandiendo: (0, 1, 1)
#   Coste: 5, Profundidad: 5
#   Frontera: 214 nodos
#
# Iteración 150 - Expandiendo: (0, 0, 2)
#   Coste: 5, Profundidad: 5
#   Frontera: 215 nodos
#
# Iteración 151 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 216 nodos
#
# Iteración 152 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 218 nodos
#
# Iteración 153 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 220 nodos
#
# Iteración 154 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 222 nodos
#
# Iteración 155 - Expandiendo: (0, 1, 6)
#   Coste: 6, Profundidad: 6
#   Frontera: 224 nodos
#
# Iteración 156 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 225 nodos
#
# Iteración 157 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 227 nodos
#
# Iteración 158 - Expandiendo: (0, 4, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 229 nodos
#
# Iteración 159 - Expandiendo: (0, 5, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 231 nodos
#
# Iteración 160 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 232 nodos
#
# Iteración 161 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 234 nodos
#
# Iteración 162 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 236 nodos
#
# Iteración 163 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 237 nodos
#
# Iteración 164 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 239 nodos
#
# Iteración 165 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 240 nodos
#
# Iteración 166 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 242 nodos
#
# Iteración 167 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 244 nodos
#
# Iteración 168 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 246 nodos
#
# Iteración 169 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 247 nodos
#
# Iteración 170 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 249 nodos
#
# Iteración 171 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 251 nodos
#
# Iteración 172 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 253 nodos
#
# Iteración 173 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 255 nodos
#
# Iteración 174 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 256 nodos
#
# Iteración 175 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 258 nodos
#
# Iteración 176 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 260 nodos
#
# Iteración 177 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 262 nodos
#
# Iteración 178 - Expandiendo: (0, 1, 6)
#   Coste: 6, Profundidad: 6
#   Frontera: 264 nodos
#
# Iteración 179 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 265 nodos
#
# Iteración 180 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 267 nodos
#
# Iteración 181 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 268 nodos
#
# Iteración 182 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 270 nodos
#
# Iteración 183 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 272 nodos
#
# Iteración 184 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 274 nodos
#
# Iteración 185 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 276 nodos
#
# Iteración 186 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 277 nodos
#
# Iteración 187 - Expandiendo: (0, 4, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 279 nodos
#
# Iteración 188 - Expandiendo: (0, 5, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 281 nodos
#
# Iteración 189 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 282 nodos
#
# Iteración 190 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 284 nodos
#
# Iteración 191 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 286 nodos
#
# Iteración 192 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 287 nodos
#
# Iteración 193 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 289 nodos
#
# Iteración 194 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 290 nodos
#
# Iteración 195 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 292 nodos
#
# Iteración 196 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 294 nodos
#
# Iteración 197 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 296 nodos
#
# Iteración 198 - Expandiendo: (0, 4, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 298 nodos
#
# Iteración 199 - Expandiendo: (0, 5, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 300 nodos
#
# Iteración 200 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 301 nodos
#
# Iteración 201 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 303 nodos
#
# Iteración 202 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 305 nodos
#
# Iteración 203 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 306 nodos
#
# Iteración 204 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 308 nodos
#
# Iteración 205 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 309 nodos
#
# Iteración 206 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 311 nodos
#
# Iteración 207 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 313 nodos
#
# Iteración 208 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 315 nodos
#
# Iteración 209 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 317 nodos
#
# Iteración 210 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 318 nodos
#
# Iteración 211 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 320 nodos
#
# Iteración 212 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 322 nodos
#
# Iteración 213 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 324 nodos
#
# Iteración 214 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 325 nodos
#
# Iteración 215 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 327 nodos
#
# Iteración 216 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 329 nodos
#
# Iteración 217 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 331 nodos
#
# Iteración 218 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 333 nodos
#
# Iteración 219 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 334 nodos
#
# Iteración 220 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 336 nodos
#
# Iteración 221 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 338 nodos
#
# Iteración 222 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 340 nodos
#
# Iteración 223 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 342 nodos
#
# Iteración 224 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 344 nodos
#
# Iteración 225 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 346 nodos
#
# Iteración 226 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 347 nodos
#
# Iteración 227 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 348 nodos
#
# Iteración 228 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 350 nodos
#
# Iteración 229 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 351 nodos
#
# Iteración 230 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 353 nodos
#
# Iteración 231 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 355 nodos
#
# Iteración 232 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 357 nodos
#
# Iteración 233 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 359 nodos
#
# Iteración 234 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 360 nodos
#
# Iteración 235 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 362 nodos
#
# Iteración 236 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 364 nodos
#
# Iteración 237 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 366 nodos
#
# Iteración 238 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 368 nodos
#
# Iteración 239 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 370 nodos
#
# Iteración 240 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 372 nodos
#
# Iteración 241 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 373 nodos
#
# Iteración 242 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 374 nodos
#
# Iteración 243 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 376 nodos
#
# Iteración 244 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 378 nodos
#
# Iteración 245 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 380 nodos
#
# Iteración 246 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 382 nodos
#
# Iteración 247 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 383 nodos
#
# Iteración 248 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 384 nodos
#
# Iteración 249 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 386 nodos
#
# Iteración 250 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 388 nodos
#
# Iteración 251 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 389 nodos
#
# Iteración 252 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 390 nodos
#
# Iteración 253 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 392 nodos
#
# Iteración 254 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 393 nodos
#
# Iteración 255 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 394 nodos
#
# Iteración 256 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 396 nodos
#
# Iteración 257 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 398 nodos
#
# Iteración 258 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 400 nodos
#
# Iteración 259 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 402 nodos
#
# Iteración 260 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 403 nodos
#
# Iteración 261 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 404 nodos
#
# Iteración 262 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 406 nodos
#
# Iteración 263 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 407 nodos
#
# Iteración 264 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 409 nodos
#
# Iteración 265 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 411 nodos
#
# Iteración 266 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 413 nodos
#
# Iteración 267 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 415 nodos
#
# Iteración 268 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 416 nodos
#
# Iteración 269 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 418 nodos
#
# Iteración 270 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 420 nodos
#
# Iteración 271 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 422 nodos
#
# Iteración 272 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 424 nodos
#
# Iteración 273 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 426 nodos
#
# Iteración 274 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 428 nodos
#
# Iteración 275 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 429 nodos
#
# Iteración 276 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 430 nodos
#
# Iteración 277 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 432 nodos
#
# Iteración 278 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 434 nodos
#
# Iteración 279 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 436 nodos
#
# Iteración 280 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 438 nodos
#
# Iteración 281 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 439 nodos
#
# Iteración 282 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 440 nodos
#
# Iteración 283 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 442 nodos
#
# Iteración 284 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 444 nodos
#
# Iteración 285 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 445 nodos
#
# Iteración 286 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 446 nodos
#
# Iteración 287 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 448 nodos
#
# Iteración 288 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 449 nodos
#
# Iteración 289 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 450 nodos
#
# Iteración 290 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 452 nodos
#
# Iteración 291 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 454 nodos
#
# Iteración 292 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 456 nodos
#
# Iteración 293 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 458 nodos
#
# Iteración 294 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 459 nodos
#
# Iteración 295 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 460 nodos
#
# Iteración 296 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 462 nodos
#
# Iteración 297 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 464 nodos
#
# Iteración 298 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 466 nodos
#
# Iteración 299 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 468 nodos
#
# Iteración 300 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 469 nodos
#
# Iteración 301 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 470 nodos
#
# Iteración 302 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 472 nodos
#
# Iteración 303 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 474 nodos
#
# Iteración 304 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 475 nodos
#
# Iteración 305 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 476 nodos
#
# Iteración 306 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 478 nodos
#
# Iteración 307 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 479 nodos
#
# Iteración 308 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 480 nodos
#
# Iteración 309 - Expandiendo: (0, 1, 6)
#   Coste: 6, Profundidad: 6
#   Frontera: 482 nodos
#
# Iteración 310 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 483 nodos
#
# Iteración 311 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 485 nodos
#
# Iteración 312 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 486 nodos
#
# Iteración 313 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 488 nodos
#
# Iteración 314 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 490 nodos
#
# Iteración 315 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 492 nodos
#
# Iteración 316 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 494 nodos
#
# Iteración 317 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 495 nodos
#
# Iteración 318 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 497 nodos
#
# Iteración 319 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 498 nodos
#
# Iteración 320 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 499 nodos
#
# Iteración 321 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 501 nodos
#
# Iteración 322 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 503 nodos
#
# Iteración 323 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 504 nodos
#
# Iteración 324 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 505 nodos
#
# Iteración 325 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 507 nodos
#
# Iteración 326 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 509 nodos
#
# Iteración 327 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 511 nodos
#
# Iteración 328 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 513 nodos
#
# Iteración 329 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 514 nodos
#
# Iteración 330 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 515 nodos
#
# Iteración 331 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 517 nodos
#
# Iteración 332 - Expandiendo: (0, 2, 5)
#   Coste: 6, Profundidad: 6
#   Frontera: 518 nodos
#
# Iteración 333 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 520 nodos
#
# Iteración 334 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 522 nodos
#
# Iteración 335 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 524 nodos
#
# Iteración 336 - Expandiendo: (0, 3, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 526 nodos
#
# Iteración 337 - Expandiendo: (0, 4, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 527 nodos
#
# Iteración 338 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 529 nodos
#
# Iteración 339 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 531 nodos
#
# Iteración 340 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 533 nodos
#
# Iteración 341 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 535 nodos
#
# Iteración 342 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 537 nodos
#
# Iteración 343 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 539 nodos
#
# Iteración 344 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 540 nodos
#
# Iteración 345 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 541 nodos
#
# Iteración 346 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 543 nodos
#
# Iteración 347 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 545 nodos
#
# Iteración 348 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 547 nodos
#
# Iteración 349 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 549 nodos
#
# Iteración 350 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 550 nodos
#
# Iteración 351 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 551 nodos
#
# Iteración 352 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 553 nodos
#
# Iteración 353 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 555 nodos
#
# Iteración 354 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 556 nodos
#
# Iteración 355 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 557 nodos
#
# Iteración 356 - Expandiendo: (0, 1, 4)
#   Coste: 6, Profundidad: 6
#   Frontera: 559 nodos
#
# Iteración 357 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 560 nodos
#
# Iteración 358 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 561 nodos
#
# Iteración 359 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 563 nodos
#
# Iteración 360 - Expandiendo: (0, 2, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 565 nodos
#
# Iteración 361 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 567 nodos
#
# Iteración 362 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 569 nodos
#
# Iteración 363 - Expandiendo: (0, 1, 0)
#   Coste: 6, Profundidad: 6
#   Frontera: 570 nodos
#
# Iteración 364 - Expandiendo: (0, 0, 3)
#   Coste: 6, Profundidad: 6
#   Frontera: 571 nodos
#
# Iteración 365 - Expandiendo: (0, 1, 2)
#   Coste: 6, Profundidad: 6
#   Frontera: 573 nodos
#
# Iteración 366 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 576 nodos
#
# Iteración 367 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 578 nodos
#
# Iteración 368 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 581 nodos
#
# Iteración 369 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 583 nodos
#
# Iteración 370 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 586 nodos
#
# Iteración 371 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 589 nodos
#
# Iteración 372 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 591 nodos
#
# Iteración 373 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 592 nodos
#
# Iteración 374 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 594 nodos
#
# Iteración 375 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 597 nodos
#
# Iteración 376 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 598 nodos
#
# Iteración 377 - Expandiendo: (0, 1, 7)
#   Coste: 7, Profundidad: 7
#   Frontera: 601 nodos
#
# Iteración 378 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 603 nodos
#
# Iteración 379 - Expandiendo: (0, 0, 6)
#   Coste: 7, Profundidad: 7
#   Frontera: 604 nodos
#
# Iteración 380 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 607 nodos
#
# Iteración 381 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 609 nodos
#
# Iteración 382 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 611 nodos
#
# Iteración 383 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 614 nodos
#
# Iteración 384 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 615 nodos
#
# Iteración 385 - Expandiendo: (0, 4, 6)
#   Coste: 7, Profundidad: 7
#   Frontera: 618 nodos
#
# Iteración 386 - Expandiendo: (0, 5, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 621 nodos
#
# Iteración 387 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 624 nodos
#
# Iteración 388 - Expandiendo: (0, 5, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 627 nodos
#
# Iteración 389 - Expandiendo: (0, 6, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 628 nodos
#
# Iteración 390 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 631 nodos
#
# Iteración 391 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 634 nodos
#
# Iteración 392 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 636 nodos
#
# Iteración 393 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 639 nodos
#
# Iteración 394 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 641 nodos
#
# Iteración 395 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 644 nodos
#
# Iteración 396 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 647 nodos
#
# Iteración 397 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 649 nodos
#
# Iteración 398 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 652 nodos
#
# Iteración 399 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 655 nodos
#
# Iteración 400 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 657 nodos
#
# Iteración 401 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 660 nodos
#
# Iteración 402 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 662 nodos
#
# Iteración 403 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 663 nodos
#
# Iteración 404 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 666 nodos
#
# Iteración 405 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 668 nodos
#
# Iteración 406 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 671 nodos
#
# Iteración 407 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 673 nodos
#
# Iteración 408 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 676 nodos
#
# Iteración 409 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 679 nodos
#
# Iteración 410 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 681 nodos
#
# Iteración 411 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 682 nodos
#
# Iteración 412 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 684 nodos
#
# Iteración 413 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 687 nodos
#
# Iteración 414 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 688 nodos
#
# Iteración 415 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 691 nodos
#
# Iteración 416 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 693 nodos
#
# Iteración 417 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 696 nodos
#
# Iteración 418 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 698 nodos
#
# Iteración 419 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 701 nodos
#
# Iteración 420 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 704 nodos
#
# Iteración 421 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 706 nodos
#
# Iteración 422 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 707 nodos
#
# Iteración 423 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 709 nodos
#
# Iteración 424 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 712 nodos
#
# Iteración 425 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 713 nodos
#
# Iteración 426 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 716 nodos
#
# Iteración 427 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 718 nodos
#
# Iteración 428 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 721 nodos
#
# Iteración 429 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 724 nodos
#
# Iteración 430 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 726 nodos
#
# Iteración 431 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 729 nodos
#
# Iteración 432 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 731 nodos
#
# Iteración 433 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 732 nodos
#
# Iteración 434 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 735 nodos
#
# Iteración 435 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 737 nodos
#
# Iteración 436 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 738 nodos
#
# Iteración 437 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 739 nodos
#
# Iteración 438 - Expandiendo: (0, 1, 1)
#   Coste: 7, Profundidad: 7
#   Frontera: 740 nodos
#
# Iteración 439 - Expandiendo: (0, 0, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 741 nodos
#
# Iteración 440 - Expandiendo: (0, 1, 7)
#   Coste: 7, Profundidad: 7
#   Frontera: 744 nodos
#
# Iteración 441 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 746 nodos
#
# Iteración 442 - Expandiendo: (0, 0, 6)
#   Coste: 7, Profundidad: 7
#   Frontera: 747 nodos
#
# Iteración 443 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 750 nodos
#
# Iteración 444 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 752 nodos
#
# Iteración 445 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 754 nodos
#
# Iteración 446 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 757 nodos
#
# Iteración 447 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 758 nodos
#
# Iteración 448 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 761 nodos
#
# Iteración 449 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 763 nodos
#
# Iteración 450 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 766 nodos
#
# Iteración 451 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 768 nodos
#
# Iteración 452 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 771 nodos
#
# Iteración 453 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 774 nodos
#
# Iteración 454 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 776 nodos
#
# Iteración 455 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 777 nodos
#
# Iteración 456 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 779 nodos
#
# Iteración 457 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 782 nodos
#
# Iteración 458 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 783 nodos
#
# Iteración 459 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 785 nodos
#
# Iteración 460 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 788 nodos
#
# Iteración 461 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 789 nodos
#
# Iteración 462 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 790 nodos
#
# Iteración 463 - Expandiendo: (0, 0, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 791 nodos
#
# Iteración 464 - Expandiendo: (0, 4, 6)
#   Coste: 7, Profundidad: 7
#   Frontera: 794 nodos
#
# Iteración 465 - Expandiendo: (0, 5, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 797 nodos
#
# Iteración 466 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 800 nodos
#
# Iteración 467 - Expandiendo: (0, 5, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 803 nodos
#
# Iteración 468 - Expandiendo: (0, 6, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 804 nodos
#
# Iteración 469 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 807 nodos
#
# Iteración 470 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 810 nodos
#
# Iteración 471 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 812 nodos
#
# Iteración 472 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 815 nodos
#
# Iteración 473 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 817 nodos
#
# Iteración 474 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 820 nodos
#
# Iteración 475 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 823 nodos
#
# Iteración 476 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 825 nodos
#
# Iteración 477 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 828 nodos
#
# Iteración 478 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 831 nodos
#
# Iteración 479 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 833 nodos
#
# Iteración 480 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 836 nodos
#
# Iteración 481 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 838 nodos
#
# Iteración 482 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 839 nodos
#
# Iteración 483 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 842 nodos
#
# Iteración 484 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 844 nodos
#
# Iteración 485 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 847 nodos
#
# Iteración 486 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 849 nodos
#
# Iteración 487 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 852 nodos
#
# Iteración 488 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 855 nodos
#
# Iteración 489 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 857 nodos
#
# Iteración 490 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 858 nodos
#
# Iteración 491 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 860 nodos
#
# Iteración 492 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 863 nodos
#
# Iteración 493 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 864 nodos
#
# Iteración 494 - Expandiendo: (0, 4, 6)
#   Coste: 7, Profundidad: 7
#   Frontera: 867 nodos
#
# Iteración 495 - Expandiendo: (0, 5, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 870 nodos
#
# Iteración 496 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 873 nodos
#
# Iteración 497 - Expandiendo: (0, 5, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 876 nodos
#
# Iteración 498 - Expandiendo: (0, 6, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 877 nodos
#
# Iteración 499 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 880 nodos
#
# Iteración 500 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 883 nodos
#
# Iteración 501 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 885 nodos
#
# Iteración 502 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 888 nodos
#
# Iteración 503 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 890 nodos
#
# Iteración 504 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 893 nodos
#
# Iteración 505 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 896 nodos
#
# Iteración 506 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 898 nodos
#
# Iteración 507 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 901 nodos
#
# Iteración 508 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 904 nodos
#
# Iteración 509 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 906 nodos
#
# Iteración 510 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 909 nodos
#
# Iteración 511 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 911 nodos
#
# Iteración 512 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 912 nodos
#
# Iteración 513 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 915 nodos
#
# Iteración 514 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 917 nodos
#
# Iteración 515 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 920 nodos
#
# Iteración 516 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 922 nodos
#
# Iteración 517 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 925 nodos
#
# Iteración 518 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 928 nodos
#
# Iteración 519 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 930 nodos
#
# Iteración 520 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 931 nodos
#
# Iteración 521 - Expandiendo: (0, 1, 5)
#   Coste: 7, Profundidad: 7
#   Frontera: 933 nodos
#
# Iteración 522 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 936 nodos
#
# Iteración 523 - Expandiendo: (0, 0, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 937 nodos
#
# Iteración 524 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 940 nodos
#
# Iteración 525 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 942 nodos
#
# Iteración 526 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 945 nodos
#
# Iteración 527 - Expandiendo: (0, 4, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 948 nodos
#
# Iteración 528 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 950 nodos
#
# Iteración 529 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 953 nodos
#
# Iteración 530 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 955 nodos
#
# Iteración 531 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 956 nodos
#
# Iteración 532 - Expandiendo: (0, 2, 4)
#   Coste: 7, Profundidad: 7
#   Frontera: 959 nodos
#
# Iteración 533 - Expandiendo: (0, 3, 3)
#   Coste: 7, Profundidad: 7
#   Frontera: 961 nodos
#
# Iteración 534 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 962 nodos
#
# Iteración 535 - Expandiendo: (0, 2, 2)
#   Coste: 7, Profundidad: 7
#   Frontera: 963 nodos
#
# Iteración 536 - Expandiendo: (0, 1, 1)
#   Coste: 7, Profundidad: 7
#   Frontera: 964 nodos
#
# ...
#   Frontera: 465 nodos
#
# Iteración 915 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 914
#   Frontera: 466 nodos
#
# Iteración 916 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 915
#   Frontera: 466 nodos
#
# Iteración 917 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 916
#   Frontera: 467 nodos
#
# Iteración 918 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 917
#   Frontera: 467 nodos
#
# Iteración 919 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 918
#   Frontera: 468 nodos
#
# Iteración 920 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 919
#   Frontera: 468 nodos
#
# Iteración 921 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 920
#   Frontera: 469 nodos
#
# Iteración 922 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 921
#   Frontera: 469 nodos
#
# Iteración 923 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 922
#   Frontera: 470 nodos
#
# Iteración 924 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 923
#   Frontera: 470 nodos
#
# Iteración 925 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 924
#   Frontera: 471 nodos
#
# Iteración 926 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 925
#   Frontera: 471 nodos
#
# Iteración 927 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 926
#   Frontera: 472 nodos
#
# Iteración 928 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 927
#   Frontera: 472 nodos
#
# Iteración 929 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 928
#   Frontera: 473 nodos
#
# Iteración 930 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 929
#   Frontera: 473 nodos
#
# Iteración 931 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 930
#   Frontera: 474 nodos
#
# Iteración 932 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 931
#   Frontera: 474 nodos
#
# Iteración 933 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 932
#   Frontera: 475 nodos
#
# Iteración 934 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 933
#   Frontera: 475 nodos
#
# Iteración 935 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 934
#   Frontera: 476 nodos
#
# Iteración 936 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 935
#   Frontera: 476 nodos
#
# Iteración 937 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 936
#   Frontera: 477 nodos
#
# Iteración 938 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 937
#   Frontera: 477 nodos
#
# Iteración 939 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 938
#   Frontera: 478 nodos
#
# Iteración 940 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 939
#   Frontera: 478 nodos
#
# Iteración 941 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 940
#   Frontera: 479 nodos
#
# Iteración 942 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 941
#   Frontera: 479 nodos
#
# Iteración 943 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 942
#   Frontera: 480 nodos
#
# Iteración 944 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 943
#   Frontera: 480 nodos
#
# Iteración 945 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 944
#   Frontera: 481 nodos
#
# Iteración 946 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 945
#   Frontera: 481 nodos
#
# Iteración 947 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 946
#   Frontera: 482 nodos
#
# Iteración 948 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 947
#   Frontera: 482 nodos
#
# Iteración 949 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 948
#   Frontera: 483 nodos
#
# Iteración 950 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 949
#   Frontera: 483 nodos
#
# Iteración 951 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 950
#   Frontera: 484 nodos
#
# Iteración 952 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 951
#   Frontera: 484 nodos
#
# Iteración 953 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 952
#   Frontera: 485 nodos
#
# Iteración 954 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 953
#   Frontera: 485 nodos
#
# Iteración 955 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 954
#   Frontera: 486 nodos
#
# Iteración 956 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 955
#   Frontera: 486 nodos
#
# Iteración 957 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 956
#   Frontera: 487 nodos
#
# Iteración 958 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 957
#   Frontera: 487 nodos
#
# Iteración 959 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 958
#   Frontera: 488 nodos
#
# Iteración 960 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 959
#   Frontera: 488 nodos
#
# Iteración 961 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 960
#   Frontera: 489 nodos
#
# Iteración 962 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 961
#   Frontera: 489 nodos
#
# Iteración 963 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 962
#   Frontera: 490 nodos
#
# Iteración 964 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 963
#   Frontera: 490 nodos
#
# Iteración 965 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 964
#   Frontera: 491 nodos
#
# Iteración 966 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 965
#   Frontera: 491 nodos
#
# Iteración 967 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 966
#   Frontera: 492 nodos
#
# Iteración 968 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 967
#   Frontera: 492 nodos
#
# Iteración 969 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 968
#   Frontera: 493 nodos
#
# Iteración 970 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 969
#   Frontera: 493 nodos
#
# Iteración 971 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 970
#   Frontera: 494 nodos
#
# Iteración 972 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 971
#   Frontera: 494 nodos
#
# Iteración 973 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 972
#   Frontera: 495 nodos
#
# Iteración 974 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 973
#   Frontera: 495 nodos
#
# Iteración 975 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 974
#   Frontera: 496 nodos
#
# Iteración 976 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 975
#   Frontera: 496 nodos
#
# Iteración 977 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 976
#   Frontera: 497 nodos
#
# Iteración 978 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 977
#   Frontera: 497 nodos
#
# Iteración 979 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 978
#   Frontera: 498 nodos
#
# Iteración 980 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 979
#   Frontera: 498 nodos
#
# Iteración 981 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 980
#   Frontera: 499 nodos
#
# Iteración 982 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 981
#   Frontera: 499 nodos
#
# Iteración 983 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 982
#   Frontera: 500 nodos
#
# Iteración 984 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 983
#   Frontera: 500 nodos
#
# Iteración 985 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 984
#   Frontera: 501 nodos
#
# Iteración 986 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 985
#   Frontera: 501 nodos
#
# Iteración 987 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 986
#   Frontera: 502 nodos
#
# Iteración 988 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 987
#   Frontera: 502 nodos
#
# Iteración 989 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 988
#   Frontera: 503 nodos
#
# Iteración 990 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 989
#   Frontera: 503 nodos
#
# Iteración 991 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 990
#   Frontera: 504 nodos
#
# Iteración 992 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 991
#   Frontera: 504 nodos
#
# Iteración 993 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 992
#   Frontera: 505 nodos
#
# Iteración 994 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 993
#   Frontera: 505 nodos
#
# Iteración 995 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 994
#   Frontera: 506 nodos
#
# Iteración 996 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 995
#   Frontera: 506 nodos
#
# Iteración 997 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 996
#   Frontera: 507 nodos
#
# Iteración 998 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 997
#   Frontera: 507 nodos
#
# Iteración 999 - Expandiendo: (0, 8, 0)
#   h(n): 6, Coste: 998
#   Frontera: 508 nodos
#
# Iteración 1000 - Expandiendo: (0, 9, 0)
#   h(n): 5, Coste: 999
#   Frontera: 508 nodos
#
# GREEDY TREE: Solución no encontrada
#
#
# --------------------------------------------------------------------------------
# EJEMPLO 6: GREEDY GRAPH - Servidor 78 (nivel 0) → Servidor 148 (nivel 1)
# --------------------------------------------------------------------------------
#
# --- INICIO GREEDY GRAPH SEARCH ---
#
# Iteración 1 - Expandiendo: (0, 6, 6)
#   h(n): 14, Coste: 0
#   Frontera: 3 nodos, Explorados: 4
#
# Iteración 2 - Expandiendo: (0, 6, 5)
#   h(n): 13, Coste: 1
#   Frontera: 5 nodos, Explorados: 7
#
# Iteración 3 - Expandiendo: (0, 6, 4)
#   h(n): 12, Coste: 2
#   Frontera: 5 nodos, Explorados: 8
#
# Iteración 4 - Expandiendo: (0, 5, 4)
#   h(n): 11, Coste: 3
#   Frontera: 5 nodos, Explorados: 9
#
# Iteración 5 - Expandiendo: (0, 4, 4)
#   h(n): 10, Coste: 4
#   Frontera: 7 nodos, Explorados: 12
#
# Iteración 6 - Expandiendo: (0, 4, 3)
#   h(n): 9, Coste: 5
#   Frontera: 7 nodos, Explorados: 13
#
# Iteración 7 - Expandiendo: (0, 3, 3)
#   h(n): 8, Coste: 6
#   Frontera: 7 nodos, Explorados: 14
#
# Iteración 8 - Expandiendo: (0, 2, 3)
#   h(n): 7, Coste: 7
#   Frontera: 8 nodos, Explorados: 16
#
# Iteración 9 - Expandiendo: (0, 2, 2)
#   h(n): 6, Coste: 8
#   Frontera: 8 nodos, Explorados: 17
#
# Iteración 10 - Expandiendo: (0, 1, 2)
#   h(n): 7, Coste: 9
#   Frontera: 9 nodos, Explorados: 19
#
# Iteración 11 - Expandiendo: (0, 1, 1)
#   h(n): 6, Coste: 10
#   Frontera: 9 nodos, Explorados: 20
#
# Iteración 12 - Expandiendo: (0, 1, 0)
#   h(n): 7, Coste: 11
#   Frontera: 9 nodos, Explorados: 21
#
# Iteración 13 - Expandiendo: (0, 2, 4)
#   h(n): 8, Coste: 8
#   Frontera: 10 nodos, Explorados: 23
#
# Iteración 14 - Expandiendo: (0, 0, 2)
#   h(n): 8, Coste: 10
#   Frontera: 10 nodos, Explorados: 24
#
# Iteración 15 - Expandiendo: (0, 0, 0)
#   h(n): 8, Coste: 12
#   Frontera: 9 nodos, Explorados: 24
#
# Iteración 16 - Expandiendo: (0, 3, 4)
#   h(n): 9, Coste: 5
#   Frontera: 8 nodos, Explorados: 24
#
# Iteración 17 - Expandiendo: (0, 2, 5)
#   h(n): 9, Coste: 9
#   Frontera: 8 nodos, Explorados: 25
#
# Iteración 18 - Expandiendo: (0, 1, 4)
#   h(n): 9, Coste: 9
#   Frontera: 8 nodos, Explorados: 26
#
# Iteración 19 - Expandiendo: (0, 0, 3)
#   h(n): 9, Coste: 11
#   Frontera: 7 nodos, Explorados: 26
#
# Iteración 20 - Expandiendo: (0, 1, 5)
#   h(n): 10, Coste: 10
#   Frontera: 7 nodos, Explorados: 27
#
# Iteración 21 - Expandiendo: (0, 0, 4)
#   h(n): 10, Coste: 10
#   Frontera: 6 nodos, Explorados: 27
#
# Iteración 22 - Expandiendo: (0, 4, 5)
#   h(n): 11, Coste: 5
#   Frontera: 7 nodos, Explorados: 29
#
# Iteración 23 - Expandiendo: (1, 4, 5)
#   h(n): 6, Coste: 6
#   Frontera: 10 nodos, Explorados: 33
#
# Iteración 24 - Expandiendo: (1, 4, 4)
#   h(n): 5, Coste: 7
#   Frontera: 11 nodos, Explorados: 35
#
# Iteración 25 - Expandiendo: (1, 4, 3)
#   h(n): 4, Coste: 8
#   Frontera: 12 nodos, Explorados: 37
#
# Iteración 26 - Expandiendo: (1, 4, 2)
#   h(n): 3, Coste: 9
#   Frontera: 13 nodos, Explorados: 39
#
# Iteración 27 - Expandiendo: (1, 3, 2)
#   h(n): 2, Coste: 10
#   Frontera: 13 nodos, Explorados: 40
#
# Iteración 28 - Expandiendo: (1, 2, 2)
#   h(n): 1, Coste: 11
#   Frontera: 15 nodos, Explorados: 43
#
# Iteración 29 - Expandiendo: (1, 2, 1)
#   h(n): 0, Coste: 12
#
# ============================================================
# ¡OBJETIVO ENCONTRADO CON GREEDY GRAPH!
# ============================================================
# Camino: [(0, 6, 6), (0, 6, 5), (0, 6, 4), (0, 5, 4), (0, 4, 4), (0, 4, 5), (1, 4, 5), (1, 4, 4), (1, 4, 3), (1, 4, 2), (1, 3, 2), (1, 2, 2), (1, 2, 1)]
# Coste total: 12
# Profundidad: 12
# Nodos en el camino: 13
# ============================================================
#
#
# --------------------------------------------------------------------------------
# EJEMPLO 7: A* TREE - Servidor 194 (nivel 1) → Servidor 159 (nivel 1)
# --------------------------------------------------------------------------------
#
# --- INICIO A* TREE SEARCH ---
#
# Iteración 1 - Expandiendo: (1, 3, 2)
#   g(n): 0, h(n): 2, f(n): 2
#   Frontera: 3 nodos
#
# Iteración 2 - Expandiendo: (1, 4, 2)
#   g(n): 1, h(n): 1, f(n): 2
#   Frontera: 5 nodos
#
# Iteración 3 - Expandiendo: (1, 5, 2)
#   g(n): 2, h(n): 0, f(n): 2
#
# ============================================================
# ¡OBJETIVO ENCONTRADO CON A* TREE!
# ============================================================
# Camino: [(1, 3, 2), (1, 4, 2), (1, 5, 2)]
# Coste total: 2
# Profundidad: 2
# Nodos en el camino: 3
# ============================================================
#
#
# --------------------------------------------------------------------------------
# EJEMPLO 8: A* GRAPH - Servidor 55 (nivel 0) → Servidor 150 (nivel 1)
# --------------------------------------------------------------------------------
#
# --- INICIO A* GRAPH SEARCH ---
#
# Iteración 1 - Expandiendo: (0, 1, 2)
#   g(n): 0, h(n): 12, f(n): 12
#   Frontera: 3 nodos, Explorados: 4
#
# Iteración 2 - Expandiendo: (0, 2, 2)
#   g(n): 1, h(n): 11, f(n): 12
#   Frontera: 3 nodos, Explorados: 5
#
# Iteración 3 - Expandiendo: (0, 2, 3)
#   g(n): 2, h(n): 10, f(n): 12
#   Frontera: 4 nodos, Explorados: 7
#
# Iteración 4 - Expandiendo: (0, 3, 3)
#   g(n): 3, h(n): 9, f(n): 12
#   Frontera: 5 nodos, Explorados: 9
#
# Iteración 5 - Expandiendo: (0, 4, 3)
#   g(n): 4, h(n): 8, f(n): 12
#   Frontera: 5 nodos, Explorados: 10
#
# Iteración 6 - Expandiendo: (0, 1, 1)
#   g(n): 1, h(n): 13, f(n): 14
#   Frontera: 5 nodos, Explorados: 11
#
# Iteración 7 - Expandiendo: (0, 0, 2)
#   g(n): 1, h(n): 13, f(n): 14
#   Frontera: 5 nodos, Explorados: 12
#
# Iteración 8 - Expandiendo: (0, 2, 4)
#   g(n): 3, h(n): 11, f(n): 14
#   Frontera: 6 nodos, Explorados: 14
#
# Iteración 9 - Expandiendo: (0, 3, 4)
#   g(n): 4, h(n): 10, f(n): 14
#   Frontera: 5 nodos, Explorados: 14
#
# Iteración 10 - Expandiendo: (0, 4, 4)
#   g(n): 5, h(n): 9, f(n): 14
#   Frontera: 6 nodos, Explorados: 16
#
# Iteración 11 - Expandiendo: (0, 0, 3)
#   g(n): 2, h(n): 12, f(n): 14
#   Frontera: 6 nodos, Explorados: 17
#
# Iteración 12 - Expandiendo: (0, 5, 4)
#   g(n): 6, h(n): 8, f(n): 14
#   Frontera: 7 nodos, Explorados: 19
#
# Iteración 13 - Expandiendo: (0, 6, 4)
#   g(n): 7, h(n): 7, f(n): 14
#   Frontera: 7 nodos, Explorados: 20
#
# Iteración 14 - Expandiendo: (0, 1, 0)
#   g(n): 2, h(n): 14, f(n): 16
#   Frontera: 7 nodos, Explorados: 21
#
# Iteración 15 - Expandiendo: (0, 2, 5)
#   g(n): 4, h(n): 12, f(n): 16
#   Frontera: 7 nodos, Explorados: 22
#
# Iteración 16 - Expandiendo: (0, 1, 4)
#   g(n): 4, h(n): 12, f(n): 16
#   Frontera: 6 nodos, Explorados: 22
#
# Iteración 17 - Expandiendo: (0, 4, 5)
#   g(n): 6, h(n): 10, f(n): 16
#   Frontera: 7 nodos, Explorados: 24
#
# Iteración 18 - Expandiendo: (1, 4, 5)
#   g(n): 7, h(n): 5, f(n): 12
#   Frontera: 10 nodos, Explorados: 28
#
# Iteración 19 - Expandiendo: (1, 5, 5)
#   g(n): 8, h(n): 4, f(n): 12
#   Frontera: 12 nodos, Explorados: 31
#
# Iteración 20 - Expandiendo: (1, 4, 4)
#   g(n): 8, h(n): 4, f(n): 12
#   Frontera: 12 nodos, Explorados: 32
#
# Iteración 21 - Expandiendo: (1, 6, 5)
#   g(n): 9, h(n): 3, f(n): 12
#   Frontera: 14 nodos, Explorados: 35
#
# Iteración 22 - Expandiendo: (1, 5, 4)
#   g(n): 9, h(n): 3, f(n): 12
#   Frontera: 13 nodos, Explorados: 35
#
# Iteración 23 - Expandiendo: (1, 4, 3)
#   g(n): 9, h(n): 3, f(n): 12
#   Frontera: 14 nodos, Explorados: 37
#
# Iteración 24 - Expandiendo: (1, 7, 5)
#   g(n): 10, h(n): 2, f(n): 12
#   Frontera: 14 nodos, Explorados: 38
#
# Iteración 25 - Expandiendo: (1, 6, 4)
#   g(n): 10, h(n): 2, f(n): 12
#   Frontera: 13 nodos, Explorados: 38
#
# Iteración 26 - Expandiendo: (1, 4, 6)
#   g(n): 8, h(n): 6, f(n): 14
#   Frontera: 14 nodos, Explorados: 40
#
# Iteración 27 - Expandiendo: (1, 3, 5)
#   g(n): 8, h(n): 6, f(n): 14
#   Frontera: 13 nodos, Explorados: 40
#
# Iteración 28 - Expandiendo: (1, 5, 6)
#   g(n): 9, h(n): 5, f(n): 14
#   Frontera: 13 nodos, Explorados: 41
#
# Iteración 29 - Expandiendo: (1, 6, 6)
#   g(n): 10, h(n): 4, f(n): 14
#   Frontera: 12 nodos, Explorados: 41
#
# Iteración 30 - Expandiendo: (1, 4, 2)
#   g(n): 10, h(n): 4, f(n): 14
#   Frontera: 13 nodos, Explorados: 43
#
# Iteración 31 - Expandiendo: (1, 3, 3)
#   g(n): 10, h(n): 4, f(n): 14
#   Frontera: 13 nodos, Explorados: 44
#
# Iteración 32 - Expandiendo: (1, 7, 6)
#   g(n): 11, h(n): 3, f(n): 14
#   Frontera: 14 nodos, Explorados: 46
#
# Iteración 33 - Expandiendo: (1, 5, 2)
#   g(n): 11, h(n): 3, f(n): 14
#   Frontera: 15 nodos, Explorados: 48
#
# Iteración 34 - Expandiendo: (1, 6, 2)
#   g(n): 12, h(n): 2, f(n): 14
#   Frontera: 16 nodos, Explorados: 50
#
# Iteración 35 - Expandiendo: (1, 7, 2)
#   g(n): 13, h(n): 1, f(n): 14
#   Frontera: 18 nodos, Explorados: 53
#
# Iteración 36 - Expandiendo: (1, 7, 3)
#   g(n): 14, h(n): 0, f(n): 14
#
# ============================================================
# ¡OBJETIVO ENCONTRADO CON A* GRAPH!
# ============================================================
# Camino: [(0, 1, 2), (0, 2, 2), (0, 2, 3), (0, 3, 3), (0, 4, 3), (0, 4, 4), (0, 4, 5), (1, 4, 5), (1, 4, 4), (1, 4, 3), (1, 4, 2), (1, 5, 2), (1, 6, 2), (1, 7, 2), (1, 7, 3)]
# Coste total: 14
# Profundidad: 14
# Nodos en el camino: 15
# ============================================================

# %% [markdown]
# ## Planificación

# %% [markdown]
# Reflexionad sobre si habéis seguido la planificación que definisteis en el Entregable CG.2. Explicad qué aspectos se cumplieron, cuáles no, y las razones que llevaron a cualquier desviación.

# %% [markdown]
# <font color="red">Manel: En mi caso, la planificación que se desarrolló al inicio de la asignatura me ha resultado
#   complicada de seguir debido al gran número de trabajos, entregas y eventos personales de
#   noviembre. Ha sido un mes de mucho estrés y de llevar las cosas al límite de la fecha de entrega.
#   Esta situación se ha ido estirando y alargando hasta afectar a un par de prácticas, incluyendo
#   esta. Sin embargo, gracias a la ampliación de tiempo, he podido desarrollar la solución de forma
#   efectiva antes de la fecha límite de entrega.</font>

# %% [markdown]
# ## Principales dudas y dificultades encontrados en el desarrollo

# %% [markdown]
# <font color="red">Manel: El contenido teórico y los principios de programación los tengo bastante claros gracias a mi
#   recorrido previo en esta asignatura y al repaso que ha supuesto este entregable. El mayor problema
#   que he enfrentado ha sido la gestión del tiempo en este desarrollo.</font>
